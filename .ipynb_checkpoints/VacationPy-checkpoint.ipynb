# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# Import API key
from gmap_keys import gmap_key

# %% [markdown]
# Store Part 1 results into DataFrame

# %%
csv_path = os.path.join("city_data.csv")
city_data_df = pd.read_csv(csv_path)
city_data_df.head()
# Out:
#    Unnamed: 0          City  Latitude  Longitude  Temperature  Humidity  \
# 0           0      khatanga     71.97     102.50        28.54        98
# 1           1     ilulissat     69.22     -51.10        19.40        57
# 2           2  punta arenas    -53.15     -70.92        32.00        90
# 3           3   east london    -33.02      27.91        62.17        79
# 4           4  quatre cocos    -20.21      57.76        70.00        93
#
#    Clouds  Winds Country        Date
# 0     100  10.29      RU  1601519973
# 1       0   6.93      GL  1601519974
# 2      20  18.34      CL  1601519974
# 3      80  18.70      ZA  1601519975
# 4      40   5.82      MU  1601519975

# %% [markdown]
# Humidity Heatmap

# %%
# Setting up for heatmap
locations = city_data_df[["Latitude", "Longitude"]]

rating = city_data_df["Humidity"].astype(float)

# %%
# Showing heatmap
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=rating, dissipating=False, max_intensity=10, point_radius=1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# Creating new DataFrame fitting weather criteria

# %%
new_cities_df = pd.DataFrame(city_data_df, columns = ["City", "Temperature", "Winds", "Clouds"])
temperature = (new_cities_df["Temperature"] <= 80) & (new_cities_df["Temperature"] > 70)
winds = new_cities_df["Winds"] > 10
clouds = new_cities_df["Clouds"] == 0

new_cities_df[temperature & winds & clouds]
# Out:
#                   City  Temperature  Winds  Clouds
# 132       sao domingos        79.99  12.03       0
# 147          carnarvon        71.60  19.46       0
# 188  sao joao da barra        73.98  18.79       0
# 349            whyalla        73.40  11.41       0

# %% [markdown]
# Hotel Map

# %%
# Creating new dataframe
hotel_df = pd.DataFrame(city_data_df, columns=["City", "Country", "Latitude", "Longitude"])

hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#            City Country  Latitude  Longitude Hotel Name
# 0      khatanga      RU     71.97     102.50
# 1     ilulissat      GL     69.22     -51.10
# 2  punta arenas      CL    -53.15     -70.92
# 3   east london      ZA    -33.02      27.91
# 4  quatre cocos      MU    -20.21      57.76

# %%
# Setting up url for hotels
target_hotel_coordinates = f"{hotel_df['Latitude'][0]},{hotel_df['Longitude'][0]}"
target_search = "hotel"
target_radius = 5000
target_type = "hotel"

params = {"location": target_hotel_coordinates,
         "keyword": target_search,
         "radius": target_radius,
         "type": target_type,
         "key": gmap_key}


base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params)

pprint(response.json(), depth=1)
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}

# %%
# Pulling url
hotel_name = []
params = {"radius": 5000,
         "types": "hotel",
         "keyword": "hotel",
         "key": gmap_key}

for index, row in hotel_df.iterrows():
    latitude = row["Latitude"]
    longitude = row["Longitude"]
    
    params["location"] = f"{latitude},{longitude}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    name_address = requests.get(base_url, params=params)
    
    name_address = name_address.json()
    
    try:
        hotel_name.append(name_address['results'][0]['name'])
    except IndexError:
        hotel_name.append(np.nan)
        
hotel_name
# Out:
# [nan,
#  'Hotel Arctic',
#  'Hotel Cabo de Hornos',
#  'Premier Hotels & Resorts',
#  "Shangri-La's Le Touessrok Resort & Spa",
#  "Land's End Boutique Hotel",
#  "Ellie's Villa",
#  'HOTEL GB',
#  'Hôtel Hiva Oa Hanakee Lodge',
#  'Los Cauquenes Resort & Spa',
#  'Café de Upernavik',
#  'Pension Bianca & Benoit',
#  'Welk Resorts Cabo San Lucas - Sirena del Mar',
#  nan,
#  nan,
#  'Pebbles Inn',
#  'One Marine Drive Boutique Hotel',
#  'Top of the World Hotel',
#  'Abbey Beach Resort',
#  'The Peninsula Hong Kong',
#  'Pacific Resort Rarotonga',
#  nan,
#  nan,
#  nan,
#  'Atlanticview Cape Town Boutique Hotel',
#  'LÜDERITZ NEST HOTEL',
#  'Hilton Garden Inn Kauai Wailua Bay',
#  nan,
#  'Royal St Andrews Hotel',
#  'Islazul Miraflores',
#  nan,
#  'Fosshotel Húsavík',
#  'Paradise First Hotel',
#  'Lanting Hotel',
#  'Esperance Chalet Village',
#  'Luminoso Lodge',
#  'Les Embruns Du Baril',
#  'Ghaseali Island Resort',
#  'Central Palace Hotel - Castro (PR)',
#  'Atlantis Hotel',
#  'Hotel Narsaq',
#  'Heritage Hotel',
#  'Maui Beach Hotel',
#  '石梅湾艾美度假酒店',
#  nan,
#  'Steppe hotel',
#  'Vardö Apartments',
#  'Grand Naniloa Hotel Hilo - a DoubleTree by Hilton',
#  nan,
#  'Qaanaaq Hotel',
#  nan,
#  'Kodiak Compass Suites',
#  "Mary-Ann's Polarrigg",
#  'Pousada Vila Di Italy',
#  'Quinta Das Buganvílias',
#  'Hilton Busan',
#  nan,
#  'Berlevåg camping & Appartement AS',
#  'Hôtel Marineau La Tuque',
#  'Grand Isla Navidad Resort',
#  'Hilton Garden Inn Sacramento Elk Grove',
#  nan,
#  'Tynwald Willow Bend Estate',
#  'Tru by Hilton North Platte',
#  'The Peacock Beach Hotel Hambantota',
#  'Drifters Motel & Restaurant',
#  'CABIN 29',
#  nan,
#  nan,
#  'Tarumã Tropical Hotel',
#  'Lidotel Hotel Boutique San Cristobal',
#  'De Hoop Collection',
#  'Umit',
#  nan,
#  'Best Western Thompson Hotel & Suites',
#  'Hyatt Regency Monterey Hotel And Spa On Del Monte Golf Course',
#  'Santal Logis',
#  'Laguna Beach Hotel & Spa',
#  nan,
#  'The Explorer Hotel',
#  'Hotel Villa Kitzia Huacho',
#  'Hotel Punta León',
#  'SkylineInn Hotel',
#  nan,
#  nan,
#  'Frobisher Inn',
#  'Coqueiro Verde',
#  'Sudu Araliya Reach Hotel',
#  'Apart Hotel Rio Xingu',
#  'Hotel Boutique Costa Del Sol',
#  'Fiordland Lodge Te Anau',
#  'Kak Doma',
#  'Lucania Palazzo Hotel',
#  'The Prestige Hotel Penang',
#  'Phofu Eco Safari Lodge',
#  nan,
#  nan,
#  'Osmani Hotel',
#  'Karem Bay',
#  'Hotel Garapacho',
#  'Best Western Plus Coco Palu',
#  'Harmon Guest House',
#  'PiscoMar Peru',
#  'Chautauqua Harbor Hotel',
#  nan,
#  'Desert Rose',
#  'The View Guesthouse - Campanario/Madeira',
#  nan,
#  'Melbu Hotel',
#  nan,
#  nan,
#  nan,
#  'Quarumanu area',
#  nan,
#  'The Adventures Inn-Peleliu',
#  'Mercure Bengkulu',
#  nan,
#  'Courtyard by Marriott Houma',
#  'InterContinental Le Moana Bora Bora',
#  nan,
#  'Codrington Gardens Bed And Breakfast',
#  nan,
#  nan,
#  'Last Light Lodge',
#  'Salamanca Wharf Hotel',
#  'Grand Vilia Hotel',
#  nan,
#  'Nusa Island Retreat',
#  'Apart Hotel Austral',
#  nan,
#  'Bay House',
#  'Taloa Heights',
#  'HOTEL ARAUJO',
#  'Embassy Suites by Hilton Lompoc Central Coast',
#  'Naujaaraaluit – Clyde River Hotel',
#  'Ózera Hotel Fazenda',
#  'The Lodge at Arrow Lakes',
#  'THE REDWOOD RIVERWALK HOTEL',
#  'Amra',
#  nan,
#  'HOTEL VIANA',
#  'Ankobra Beach',
#  'InterContinental Bora Bora Resort Thalasso Spa',
#  'Arktika',
#  'Sails in the Desert',
#  'Lemon Tree Lane Guest House',
#  'Hotel Paloma',
#  'Carnarvon Motel',
#  'Gulele Hotel',
#  nan,
#  nan,
#  'Hostal Plaza Lebu',
#  'Bonthe Holiday Village',
#  'Chukotka hotel',
#  nan,
#  nan,
#  'Gostinichnyy Kompleks Aylgy',
#  'Hotel Qaqortoq',
#  'Hotel Gaúcho',
#  'Hôtel Raiatea Lodge',
#  'Yako',
#  'Baza Otdykha Kak Doma',
#  'Hotel Folkloro Sanriku Kamaishi',
#  'The Westin Resort & Spa, Puerto Vallarta',
#  "Arìa Residenze d'aMare",
#  '別邸 海と森',
#  'Hotel Puerto de Vega',
#  "Grands' Guesthouse",
#  'Hotel Vestmannaeyjar',
#  'Hotel Santiago',
#  nan,
#  'Gospel Fazenda Park Hotel',
#  'Pickerel Bay Cabins',
#  'Motel La Banio',
#  'Kangcheng Jian Guo International Hotel',
#  'Tiongkok Kecil Heritage Lasem',
#  'Courtyard by Marriott Abilene Northeast',
#  'Bedouin Hotel & Suites',
#  "Munitsipal'naya Gostinitsa",
#  nan,
#  'Vienna Hotel Shanwei Lufeng Jieshi Bus Station',
#  'Splash Guest House',
#  'Yalemd',
#  'Hotel Angmagssalik',
#  'Pension Feldgärtenhof',
#  'HOTEL CHEZ JIMMY',
#  'Hotel Polo Orchid',
#  'Sophia II Residence Inn',
#  'Pousada Porto Prime',
#  nan,
#  'Hotel Lago Dourado',
#  'Geilin Bed & Breakfast',
#  "BARBER'S FARM AND RESORT",
#  'Sheraton Lima Hotel & Convention Center',
#  'The Gerald Apartment Hotel',
#  'ATLAS HOTEL',
#  'Hotel Castrum Villae',
#  'Hôtel Opémiska',
#  'Hotel Marshfield',
#  'Bertelli Chuí Hotel',
#  '哈密环球大酒店',
#  'Roma Zee Guest House Annex',
#  'Seeadler Bay Hotel',
#  'Yubileynaya',
#  nan,
#  'Hotel Vermont Plaza',
#  nan,
#  nan,
#  nan,
#  'Iceberg Inn',
#  'Hotel Santiago',
#  nan,
#  'Ritz Lauca',
#  nan,
#  'Hotel Ust-Nera',
#  'HOTEL BOUTIQUE PALACIO ICO',
#  'OYO 598 Peony Hotel',
#  'Hotel Guanaja',
#  'Palette - The Citi Residenci',
#  'Chenango Valley State Park',
#  nan,
#  'Casagrande Apart Hotel',
#  nan,
#  nan,
#  'Hotel Jardines Baja',
#  nan,
#  'Holiday Inn Mauritius Mon Tresor',
#  'Liamo Reef Resort - Kimbe International Hotel',
#  'Hotel Tropical',
#  "Hunter's B&B",
#  'Castaways Cottages',
#  'Mövenpick Hotel Qassim',
#  'Manbej City Hotel',
#  nan,
#  'Hôtel Côte et Lac',
#  'Occidental Lanzarote Playa',
#  'Squatters Homestead Motel',
#  'Nomades Hotel Boutique',
#  'Jungle Bay Resort & Spa',
#  nan,
#  'Graciosa Resort - Biosphere Island Hotel',
#  'Four Seasons Hotel Alexandria at San Stefano, Egypt',
#  nan,
#  "Motel L'Archipel Inc",
#  'Parador de Ferrol',
#  nan,
#  nan,
#  'Hotel Praia do Sol',
#  'Við Hafið Guesthouse',
#  nan,
#  'Pensiunea Sophia',
#  'Hostal Aldea del Elqui',
#  'Victoria Inn Flin Flon',
#  'Hudhuveli Maldives',
#  'Bow Island Lodge',
#  'فندق رستا بورسعيد Resta Port Said Hotel',
#  'Super 8 by Wyndham Kapuskasing',
#  'A Villa by the Sea',
#  nan,
#  'Entabeni Hotel',
#  nan,
#  '"Plantation Bed and Breakfast',
#  'Party Beach Resort',
#  'Maryfield House Hotel Ltd',
#  'iu Hotel Kuíto',
#  'Le Chateau Du Bost',
#  'Black Rock Oceanfront Resort',
#  'Aloft Alpharetta',
#  'Turtle Nest Inn & Condos',
#  nan,
#  'Aroma Stone Hotel Spa',
#  'RedDoorz near Stadion Prasamya Majene',
#  'Hotel Flasso 1',
#  'Hotel Los Caracoles',
#  'Hotel Maresta Lodge',
#  'Hilton Port Moresby',
#  'Bahay ni Singkit',
#  nan,
#  nan,
#  'Hotel Kawissa Saurimo',
#  'Hacienda Santana',
#  'Hampton Inn Danbury',
#  nan,
#  'Home2 Suites by Hilton Pecos',
#  'Barrack Point Holidays',
#  'SpringHill Suites by Marriott Fairbanks',
#  'Hotel Barun Sankhuwasabha',
#  'Tianyuan International Hotel',
#  'Hotel National',
#  'Las Mañanitas - Casa Hotel',
#  nan,
#  'Sberbank Rossii',
#  'Hotel Kap Farvel',
#  'ЛУКОЙЛ #101, АЗС',
#  'Cullinan Premier Hotel',
#  'ณิสาญ์สิริ บูติค รีสอร์ท แหลมสิงห์ จันทบุรี',
#  nan,
#  'Hotel Cesar',
#  'Bulls and Anchor Inn',
#  nan,
#  'Fortune Resort Bay Island',
#  'Ngorongoro Serena Safari Lodge',
#  'Botany Bay Hotel',
#  'Гостиница Сарканд',
#  'Hotel Traful',
#  'Alrwasi Hotel',
#  nan,
#  '7Days Premium Heihe Nenjiang County Keyun Station Branch',
#  nan,
#  'K-POP HOTEL Seoul Tower',
#  'Mbathior Hôtel',
#  'Jiamusi Haitian Hotel',
#  nan,
#  'Riu Hotels Maldives',
#  nan,
#  'Air Manis Hill Residence',
#  'Guest House Comfort-House-Balkhash',
#  'Otel\' "Medvezh\'ye"',
#  nan,
#  'Pestana Porto Santo',
#  'Holiday Inn Express & Suites Alpena - Downtown',
#  'Kysthotellet Rørvik AS',
#  'DoubleTree by Hilton Hotel Alice Springs',
#  'TDC Village (Hundred Man Camp)',
#  nan,
#  'Hotel Timpton',
#  nan,
#  "Painter's Lodge",
#  'The Westin Chongqing Liberation Square',
#  'Profilaktoriy Baes',
#  'Grand Kecubung Hotel',
#  nan,
#  'Hilton Hotel',
#  'Dolphin Hotel',
#  "Pike's Waterfront Lodge",
#  'White Elephant Nantucket',
#  'Free Zone Hotel Nouadhibou',
#  'HOTEL ELENA',
#  'Lagoa Hotel Porangatu',
#  'Villa-Malaza',
#  'AC Hotel by Marriott Palacio de Santa Ana',
#  'Pacific Harbour Lodge',
#  'Lae City Hotel',
#  'The Ritz-Carlton, Half Moon Bay',
#  'Magnolias Cottage',
#  'Oval Hotel',
#  'Auyuittuq Lodge (Inns North)',
#  'Pezula Resort Hotel & Spa',
#  nan,
#  'Sundowner Motel Hotel',
#  'Winnock Hotel',
#  'Shache Hotel',
#  'Hotel de Bourgtheroulde, Autograph Collection',
#  'HOTEL LA PROVIDENCE',
#  'Walkabout Lodge & Tavern',
#  '„RYBAK” Ośrodek Wypoczynkowy i Restauracja',
#  nan,
#  'Polyarnaya Zvezda',
#  'Royal Amazonia',
#  'Osprey Beach Hotel',
#  nan,
#  'Mini Hotel Gostinka',
#  'Beira Terrace Hotel',
#  'Jesus Antonio Burgos Salazar',
#  nan,
#  nan,
#  'Hattusa Vacation Thermal Club Erzin',
#  'Hotel complex Pastoral',
#  'Dream of Baikal Hotel',
#  nan,
#  'AIDIA Grande Hotel',
#  nan,
#  'Protea Hotel by Marriott Saldanha Bay',
#  'Luxury Hotel',
#  'Sundog Inn',
#  'Hotel Náutico de Paita',
#  nan,
#  'Druzhba',
#  'Best Western Plus Mirage Hotel & Resort',
#  nan,
#  'Eriboma Executive Lodge',
#  'Hotel Hacienda de Abajo',
#  'Colonial Guest House of Fogo',
#  'Hilton Garden Inn St. George',
#  nan,
#  'Hampton Inn & Suites Mountain Home',
#  'Hilton Garden Inn Norwalk',
#  'Hotel FK Paso de los Toros',
#  'Hotel Copacabana',
#  'Flamingo Lodge Motel',
#  'Zum Löwen',
#  'Domaine de Saint-Clair',
#  'Canalta Hotel Assiniboia',
#  'San Biagio Relais',
#  'Jinyue International Hotel',
#  'Silver House Hotel',
#  'Dikukama Hotel',
#  nan,
#  'Swiss-Belhotel Ambon',
#  nan,
#  'Hotel Jr',
#  nan,
#  nan,
#  'Talnakh Hotel',
#  'Terranea Resort',
#  'Quest Hotel San Denpasar',
#  nan,
#  'la Maison de la Fontaine',
#  nan,
#  'la casona de juancho',
#  'Hotel Europe Kropotkin',
#  'hotel luna del desierto',
#  'The View',
#  'Grand Mercure Puka Park Resort',
#  'Livingston Hotel Sandakan',
#  'Casa Rodo 53',
#  nan,
#  'Zhangjiakou Venice Hotel',
#  'Grand Mercure Qingdao Pingdu',
#  'Hotel Elite',
#  'GetZleep Pool Villa Sattahip',
#  'Lofoten Værøy Brygge',
#  'Hotel Macuco',
#  'OYO 37044 Hotel Vidur Pukhrayan',
#  'Hilton Garden Inn Santo André',
#  'Red Stone',
#  'Black Mamba',
#  nan,
#  'Hotel Alice',
#  nan,
#  'Pousada Encanto Abrolhos',
#  'Gametxo hotela',
#  'Hotel Puerto del Sol',
#  'HP Red Sea Hotel',
#  'Country Pathfinder Motor Inn',
#  nan,
#  'Best Western Bundaberg City Motor Inn',
#  'Glen Lyon Inn',
#  'Porto Suites Natal Hotel',
#  'Hyatt Place Riyadh Al Sulaimania',
#  nan,
#  'Stylos Hall Hotel',
#  'Hostal De Pedri',
#  'Bismillah Hotel And Lodging',
#  'Desert Gat',
#  nan,
#  'Aparthotel Simpsiönkullas',
#  'Le Fornaci Imperial Lodge & Spa',
#  'The Bottle-O - Goondi Hill Hotel',
#  'Mingjiang International Hotel',
#  'The Astra',
#  'STAYERY Bielefeld',
#  nan,
#  'Kemka',
#  nan,
#  'Beringgorski',
#  'Logis Hôtel de la Chaussée',
#  "The Trainmaster's Inn",
#  'Villavela Hotel Boutique',
#  'Havøysund Hotel & Rorbuer',
#  'Parakai Springs Lodge',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Vas.VOM',
#  'Hotel Coral Beach',
#  nan,
#  nan,
#  'The Dadhikar Fort',
#  nan,
#  'Hotel- Galería "Las brisas"',
#  'Hotel Miramar',
#  'Wantong Hotel',
#  'Hotel Ivaana',
#  'HOSPEDAJE SANTA CRUZ',
#  'OYO Hotel Los Arcos',
#  'Seth Thee Residence',
#  nan,
#  'Orosi Valley Hotel and Villas',
#  'Cree Village Eco Lodge',
#  'Paradise reef resort',
#  'Hotel Resende',
#  'Baza Otdykha "Prichal"',
#  'Hôtel Telwa Bungalow',
#  'Гостиница "Savoy"',
#  'House 7 Resort',
#  'HOTEL LA FUENTE J.N',
#  "L'oiseau de Paradis",
#  'Namatanai Hotel',
#  nan,
#  'Noto Wajima Onsen Hotel Koshuen',
#  'Rédidence OUADADA',
#  'Kimberleyland Waterfront Holiday Park | Kununurra Accommodation',
#  'Pechenga',
#  'Aleksandrovskiy',
#  'The Roost Bed and Breakfast',
#  nan,
#  'Mais Hotel Balsas',
#  'Liber Hotel Nova Serrana',
#  'The Bayside Bed and Breakfast',
#  nan,
#  'Nile Palace Hotel',
#  nan,
#  'Hotel Uaupes',
#  'Le clos des pensées',
#  nan,
#  'Mystic Sands',
#  'HYATT SALALAH HOTEL',
#  'Hotel Gonçalves',
#  'Encanto Acapulco',
#  'Hotel Concha do Mar',
#  'Hotel Vila Gale Touros',
#  'dorehamy',
#  'San Ramon Marriott',
#  'Gladstone Heights Harbour View Executive Apartments',
#  'KYUKAMURA RIKUCHU-MIYAKO',
#  'The Celtic Manor Resort',
#  'Dazzler by Wyndham Puerto Madryn',
#  nan,
#  'Bahay ni Singkit',
#  'Gostinitsa',
#  'Hoian Nostalgia Hotel & Spa',
#  "The Old Salt Box Co. Skinner's House Burgeo",
#  'Hotel Meuligoe',
#  nan,
#  'Hilton Garden Inn Qidong',
#  'Gostevoy Dom "Brusnika"',
#  'Harbour View',
#  "Zapolyar'ye, Gostinitsa",
#  'Juddi Hotel',
#  'The Duniway Portland, A Hilton Hotel',
#  nan,
#  'DoubleTree by Hilton Hotel Ontario Airport',
#  'Palacio de Pujadas by MIJ',
#  nan,
#  'Sitka Hotel',
#  'Gweta Lodge',
#  nan,
#  'Hotel VOYAGE',
#  'Hotel Ritz Sumbe',
#  'Dreamland Golf Hotel Baku',
#  'Rydges Port Macquarie',
#  'Raqui Lodge',
#  'Vestavind Hytter og Rom AS',
#  "Turner's Northwoods Adventures",
#  "Usad'ba",
#  'Megaron Hotel',
#  'Apart Hotel Santiago',
#  nan,
#  'SpringHill Suites by Marriott Gallup',
#  nan,
#  'Hotel Las Vegas',
#  'Riad Fes - Relais & Châteaux',
#  'Semnan Traditional Hotel',
#  'HOTEL GOLDEN INN',
#  'Whitsunday Sands Resort',
#  'Hotel Zumrat',
#  'Crest Hotel',
#  'Hotel Arsenev',
#  nan,
#  'Swarg Exotica',
#  'Real Hotel',
#  'alkhairat hotel',
#  'Hampton Inn by Hilton North Bay',
#  'Floresta Amazonica Hotel',
#  'Birdwing Butterfly Lodge',
#  nan,
#  nan,
#  nan,
#  'Quality Inn',
#  'Paradise Bay Resort',
#  'Montta - active camping / campsite Montan',
#  'Hotel Museo Casona Ugarte Leon',
#  'ВИЛА-Н, гостевой дом',
#  'Sky Villa Boutique Hotel',
#  'Fine Days Hotel',
#  'MGM Hotel',
#  nan,
#  'Shapur Hotel',
#  'Rede Beach: Hotel em Guajiru',
#  'Malmaison Aberdeen',
#  nan,
#  nan,
#  'Casa De Olas Boutique Hotel',
#  'Panamericana Hotel Ancud',
#  'Dongguan Hotel']

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heatmap
fig.add_layer(gmaps.heatmap_layers(locations))
fig = gmaps.figure(layout={
    'width': '400px',
    'height': '600px',
    'padding': '3px',
    'border': '1px solid black'
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8589e4621fde> in <module>
#       1 # Add marker layer ontop of heatmap
# ----> 2 fig.add_layer(gmaps.heatmap_layers(locations))
#       3 fig = gmaps.figure(layout={
#       4     'width': '400px',
#       5     'height': '600px',
#
# AttributeError: module 'gmaps' has no attribute 'heatmap_layers'

# %%
# Display figure
fig = gmaps.figure(map_type='HYBRID')
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
