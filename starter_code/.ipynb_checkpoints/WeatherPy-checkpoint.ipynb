# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from random import uniform
# Import API key
from api_keys import weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Output File (CSV)
output_data_file = "output_data/cities.csv"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1600)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        # Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %%
city_list = pd.DataFrame(cities)
city_list.head()
# Out:
#            0
# 0    kampene
# 1    ushuaia
# 2     albany
# 3  mount isa
# 4     lumeje

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

units = "Imperial"

query_url = f"{url}appid={weather_api_key}&units={units}"

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial

# %%
all_city_data = []
for city in cities:
    city_url = query_url + "&q=" + city
    try:
        city_weather = requests.get(city_url).json()
        print(json.dumps(city_weather, indent=4, sort_keys=True))    
        print(city_url)
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_temperature = city_weather["main"]["temp_max"]
        city_humid = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        all_city_data.append({"City": city, 
                              "Latitude": city_lat,
                              "Longitude": city_lon,
                              "Temperature": city_temperature,
                              "Humidity": city_humid,
                              "Clouds": city_clouds,
                              "Wind": city_wind,
                              "Country": city_country,
                              "Date": city_date})
    except:
        print("City not found")
        pass
    #break

# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.6,
#         "lon": 26.67
#     },
#     "dt": 1601423260,
#     "id": 214575,
#     "main": {
#         "feels_like": 70.95,
#         "grnd_level": 939,
#         "humidity": 97,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 66.45,
#         "temp_max": 66.45,
#         "temp_min": 66.45
#     },
#     "name": "Kampene",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1601438345,
#         "sunset": 1601482033
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 13,
#         "speed": 1.86
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kampene
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1601423196,
#     "id": 3833367,
#     "main": {
#         "feels_like": 18.23,
#         "humidity": 86,
#         "pressure": 986,
#         "temp": 33.8,
#         "temp_max": 33.8,
#         "temp_min": 33.8
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1601373743,
#         "sunset": 1601419450,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 5000,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 20.8
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ushuaia
# {
#     "base": "stations",
#     "clouds": {
#         "all": 79
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6,
#         "lon": -73.97
#     },
#     "dt": 1601423222,
#     "id": 5106841,
#     "main": {
#         "feels_like": 59.36,
#         "humidity": 77,
#         "pressure": 1006,
#         "temp": 61.2,
#         "temp_max": 62.01,
#         "temp_min": 60.01
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 19530,
#         "sunrise": 1601376675,
#         "sunset": 1601419239,
#         "type": 3
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 319,
#         "speed": 5.41
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=albany
# {
#     "base": "stations",
#     "clouds": {
#         "all": 10
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.73,
#         "lon": 139.5
#     },
#     "dt": 1601423261,
#     "id": 2065594,
#     "main": {
#         "feels_like": 83.34,
#         "humidity": 32,
#         "pressure": 1015,
#         "temp": 84.2,
#         "temp_max": 84.2,
#         "temp_min": 84.2
#     },
#     "name": "Mount Isa",
#     "sys": {
#         "country": "AU",
#         "id": 9495,
#         "sunrise": 1601411046,
#         "sunset": 1601455186,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "speed": 2.24
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mount isa
# {
#     "base": "stations",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -11.55,
#         "lon": 20.78
#     },
#     "dt": 1601423261,
#     "id": 876123,
#     "main": {
#         "feels_like": 69.31,
#         "grnd_level": 888,
#         "humidity": 80,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 69.31,
#         "temp_max": 69.31,
#         "temp_min": 69.31
#     },
#     "name": "Lumeje",
#     "rain": {
#         "1h": 0.69
#     },
#     "sys": {
#         "country": "AO",
#         "sunrise": 1601439654,
#         "sunset": 1601483551
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 7.81
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=lumeje
# {
#     "base": "stations",
#     "clouds": {
#         "all": 74
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.28,
#         "lon": 169.85
#     },
#     "dt": 1601423262,
#     "id": 2208248,
#     "main": {
#         "feels_like": 41.27,
#         "humidity": 66,
#         "pressure": 1013,
#         "temp": 46.99,
#         "temp_max": 46.99,
#         "temp_min": 46.99
#     },
#     "name": "Kaitangata",
#     "sys": {
#         "country": "NZ",
#         "id": 2000217,
#         "sunrise": 1601403243,
#         "sunset": 1601448424,
#         "type": 3
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "gust": 15.01,
#         "speed": 5.01
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kaitangata
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.67,
#         "lon": -17.1
#     },
#     "dt": 1601423262,
#     "id": 2264557,
#     "main": {
#         "feels_like": 68.7,
#         "humidity": 73,
#         "pressure": 1021,
#         "temp": 68.79,
#         "temp_max": 69.8,
#         "temp_min": 68
#     },
#     "name": "Ponta do Sol",
#     "sys": {
#         "country": "PT",
#         "id": 6894,
#         "sunrise": 1601449315,
#         "sunset": 1601492067,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 5.82
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ponta do sol
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.92
#     },
#     "dt": 1601423263,
#     "id": 3874787,
#     "main": {
#         "feels_like": 16.38,
#         "humidity": 82,
#         "pressure": 993,
#         "temp": 33.4,
#         "temp_max": 33.8,
#         "temp_min": 33.01
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1601374438,
#         "sunset": 1601420013,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower sleet",
#             "icon": "13n",
#             "id": 612,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "speed": 23.04
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=punta arenas
# {
#     "base": "stations",
#     "clouds": {
#         "all": 6
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.23
#     },
#     "dt": 1601423263,
#     "id": 3366880,
#     "main": {
#         "feels_like": 43.03,
#         "humidity": 92,
#         "pressure": 1023,
#         "temp": 46.99,
#         "temp_max": 46.99,
#         "temp_min": 46.99
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1601439646,
#         "sunset": 1601484303,
#         "type": 3
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 68,
#         "speed": 4.88
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=hermanus
# {
#     "base": "stations",
#     "clouds": {
#         "all": 57
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.88,
#         "lon": 112.21
#     },
#     "dt": 1601423263,
#     "id": 8079926,
#     "main": {
#         "feels_like": 83.5,
#         "grnd_level": 1010,
#         "humidity": 73,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 79.95,
#         "temp_max": 79.95,
#         "temp_min": 79.95
#     },
#     "name": "Labuhan",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1601417781,
#         "sunset": 1601461548
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 182,
#         "speed": 7.7
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=labuhan
# {
#     "base": "stations",
#     "clouds": {
#         "all": 50
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38,
#         "lon": -57.56
#     },
#     "dt": 1601423104,
#     "id": 3430863,
#     "main": {
#         "feels_like": 59.88,
#         "humidity": 59,
#         "pressure": 1007,
#         "temp": 64.4,
#         "temp_max": 64.4,
#         "temp_min": 64.4
#     },
#     "name": "Mar del Plata",
#     "sys": {
#         "country": "AR",
#         "id": 8305,
#         "sunrise": 1601371669,
#         "sunset": 1601416370,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 8.05
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mar del plata
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mizpe ramon
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 76
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.16,
#         "lon": -8.33
#     },
#     "dt": 1601423264,
#     "id": 2738381,
#     "main": {
#         "feels_like": 58.68,
#         "humidity": 85,
#         "pressure": 1020,
#         "temp": 58.44,
#         "temp_max": 64,
#         "temp_min": 53.01
#     },
#     "name": "Lata",
#     "sys": {
#         "country": "PT",
#         "id": 2016210,
#         "sunrise": 1601447331,
#         "sunset": 1601489843,
#         "type": 3
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 325,
#         "speed": 1.77
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=lata
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.72,
#         "lon": -25.43
#     },
#     "dt": 1601423264,
#     "id": 3372472,
#     "main": {
#         "feels_like": 63.21,
#         "humidity": 72,
#         "pressure": 1027,
#         "temp": 66.2,
#         "temp_max": 66.2,
#         "temp_min": 66.2
#     },
#     "name": "Vila Franca do Campo",
#     "sys": {
#         "country": "PT",
#         "id": 6899,
#         "sunrise": 1601364944,
#         "sunset": 1601407677,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 9.17
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=vila franca do campo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.05,
#         "lon": -73.72
#     },
#     "dt": 1601423265,
#     "id": 6117611,
#     "main": {
#         "feels_like": 55.4,
#         "humidity": 94,
#         "pressure": 787,
#         "temp": 57.34,
#         "temp_max": 57.99,
#         "temp_min": 57
#     },
#     "name": "Rawdon",
#     "rain": {
#         "1h": 1.15
#     },
#     "sys": {
#         "country": "CA",
#         "id": 2011497,
#         "sunrise": 1601376674,
#         "sunset": 1601419120,
#         "type": 3
#     },
#     "timezone": -14400,
#     "visibility": 3201,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 170,
#         "speed": 6.58
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=rawdon
# {
#     "base": "stations",
#     "clouds": {
#         "all": 19
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.2,
#         "lon": -35.46
#     },
#     "dt": 1601423152,
#     "id": 3386213,
#     "main": {
#         "feels_like": 80.78,
#         "humidity": 83,
#         "pressure": 1015,
#         "temp": 75.2,
#         "temp_max": 75.2,
#         "temp_min": 75.2
#     },
#     "name": "Touros",
#     "sys": {
#         "country": "BR",
#         "id": 8452,
#         "sunrise": 1601366859,
#         "sunset": 1601410575,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 3.36
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=touros
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -17,
#         "lon": 145.43
#     },
#     "dt": 1601423265,
#     "id": 2158767,
#     "main": {
#         "feels_like": 75.06,
#         "humidity": 60,
#         "pressure": 1020,
#         "temp": 75.07,
#         "temp_max": 79,
#         "temp_min": 71.01
#     },
#     "name": "Mareeba",
#     "sys": {
#         "country": "AU",
#         "id": 2010006,
#         "sunrise": 1601409678,
#         "sunset": 1601453709,
#         "type": 3
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 98,
#         "gust": 18.01,
#         "speed": 5.99
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mareeba
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=belushya guba
# City not found
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kazalinsk
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.04,
#         "lon": 14.43
#     },
#     "dt": 1601423266,
#     "id": 2212775,
#     "main": {
#         "feels_like": 74.41,
#         "grnd_level": 967,
#         "humidity": 19,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 82.53,
#         "temp_max": 82.53,
#         "temp_min": 82.53
#     },
#     "name": "Sabha",
#     "sys": {
#         "country": "LY",
#         "sunrise": 1601441665,
#         "sunset": 1601484587
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 105,
#         "speed": 9.19
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=sabha
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1601423219,
#     "id": 6201424,
#     "main": {
#         "feels_like": 41.27,
#         "humidity": 92,
#         "pressure": 1016,
#         "temp": 46.99,
#         "temp_max": 46.99,
#         "temp_min": 46.99
#     },
#     "name": "Mataura",
#     "rain": {
#         "1h": 0.13
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1601403483,
#         "sunset": 1601448660,
#         "type": 3
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 257,
#         "gust": 17,
#         "speed": 8.01
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mataura
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kuche
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.47,
#         "lon": -105.12
#     },
#     "dt": 1601423267,
#     "id": 4004161,
#     "main": {
#         "feels_like": 88.48,
#         "humidity": 74,
#         "pressure": 1015,
#         "temp": 82.4,
#         "temp_max": 82.4,
#         "temp_min": 82.4
#     },
#     "name": "Jalcocot\u00e1n",
#     "sys": {
#         "country": "MX",
#         "id": 7127,
#         "sunrise": 1601383872,
#         "sunset": 1601426991,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 5.82
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=jalcocotan
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1601423240,
#     "id": 1015776,
#     "main": {
#         "feels_like": 48.07,
#         "humidity": 81,
#         "pressure": 1023,
#         "temp": 50,
#         "temp_max": 50,
#         "temp_min": 50
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "sunrise": 1601439449,
#         "sunset": 1601484110,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 1.12
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=bredasdorp
# {
#     "base": "stations",
#     "clouds": {
#         "all": 66
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -37.62,
#         "lon": -73.65
#     },
#     "dt": 1601423267,
#     "id": 3883457,
#     "main": {
#         "feels_like": 37.6,
#         "grnd_level": 1003,
#         "humidity": 85,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 48.83,
#         "temp_max": 48.83,
#         "temp_min": 48.83
#     },
#     "name": "Lebu",
#     "rain": {
#         "1h": 0.44
#     },
#     "sys": {
#         "country": "CL",
#         "sunrise": 1601375535,
#         "sunset": 1601420226
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 303,
#         "speed": 17.69
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=lebu
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.05,
#         "lon": 39.51
#     },
#     "dt": 1601422974,
#     "id": 556268,
#     "main": {
#         "feels_like": 33.19,
#         "grnd_level": 1020,
#         "humidity": 79,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 46.06,
#         "temp_max": 46.06,
#         "temp_min": 46.06
#     },
#     "name": "Ostrovnoy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601436723,
#         "sunset": 1601477493
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 228,
#         "speed": 18.88
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ostrovnoy
# {
#     "base": "stations",
#     "clouds": {
#         "all": 23
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.21,
#         "lon": -159.78
#     },
#     "dt": 1601423210,
#     "id": 4035715,
#     "main": {
#         "feels_like": 75.42,
#         "humidity": 74,
#         "pressure": 1017,
#         "temp": 80.6,
#         "temp_max": 80.6,
#         "temp_min": 80.6
#     },
#     "name": "Avarua",
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1601396476,
#         "sunset": 1601440618,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 24.16
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=avarua
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.77,
#         "lon": 114.6
#     },
#     "dt": 1601423103,
#     "id": 2070998,
#     "main": {
#         "feels_like": 47.46,
#         "humidity": 87,
#         "pressure": 1018,
#         "temp": 51.8,
#         "temp_max": 51.8,
#         "temp_min": 51.8
#     },
#     "name": "Geraldton",
#     "sys": {
#         "country": "AU",
#         "id": 9522,
#         "sunrise": 1601416887,
#         "sunset": 1601461295,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 6.93
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=geraldton
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.72,
#         "lon": 8.78
#     },
#     "dt": 1601423248,
#     "id": 2396518,
#     "main": {
#         "feels_like": 81.77,
#         "humidity": 88,
#         "pressure": 1013,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Port-Gentil",
#     "sys": {
#         "country": "GA",
#         "id": 2188,
#         "sunrise": 1601442673,
#         "sunset": 1601486290,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 8.05
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=port-gentil
# {
#     "base": "stations",
#     "clouds": {
#         "all": 11
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1601423269,
#     "id": 4020109,
#     "main": {
#         "feels_like": 75.97,
#         "grnd_level": 1009,
#         "humidity": 71,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 78.73,
#         "temp_max": 78.73,
#         "temp_min": 78.73
#     },
#     "name": "Atuona",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1601391652,
#         "sunset": 1601435484
#     },
#     "timezone": -34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 105,
#         "speed": 17.13
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=atuona
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.24,
#         "lon": 130.99
#     },
#     "dt": 1601423233,
#     "id": 6355222,
#     "main": {
#         "feels_like": 63.03,
#         "humidity": 56,
#         "pressure": 1018,
#         "temp": 69.8,
#         "temp_max": 69.8,
#         "temp_min": 69.8
#     },
#     "name": "Yulara",
#     "sys": {
#         "country": "AU",
#         "id": 9487,
#         "sunrise": 1601413017,
#         "sunset": 1601457300,
#         "type": 1
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 13.87
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=yulara
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.41,
#         "lon": 57.7
#     },
#     "dt": 1601423250,
#     "id": 934322,
#     "main": {
#         "feels_like": 73.65,
#         "humidity": 88,
#         "pressure": 1018,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Mah\u00e9bourg",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1601430670,
#         "sunset": 1601474817,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 8.05
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mahebourg
# {
#     "base": "stations",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.02,
#         "lon": 27.91
#     },
#     "dt": 1601423100,
#     "id": 1006984,
#     "main": {
#         "feels_like": 56.43,
#         "grnd_level": 1020,
#         "humidity": 68,
#         "pressure": 1024,
#         "sea_level": 1024,
#         "temp": 58.28,
#         "temp_max": 58.28,
#         "temp_min": 58.28
#     },
#     "name": "East London",
#     "rain": {
#         "1h": 0.11
#     },
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1601437594,
#         "sunset": 1601482189
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 305,
#         "speed": 2.42
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=east london
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.7,
#         "lon": 30.79
#     },
#     "dt": 1601423269,
#     "id": 546105,
#     "main": {
#         "feels_like": 50.27,
#         "humidity": 87,
#         "pressure": 1022,
#         "temp": 51.93,
#         "temp_max": 52,
#         "temp_min": 51.8
#     },
#     "name": "Nikolskoye",
#     "sys": {
#         "country": "RU",
#         "id": 8926,
#         "sunrise": 1601438415,
#         "sunset": 1601479986,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 2300,
#     "weather": [
#         {
#             "description": "fog",
#             "icon": "50n",
#             "id": 741,
#             "main": "Fog"
#         },
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 2.24
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=nikolskoye
# {
#     "base": "stations",
#     "clouds": {
#         "all": 65
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.82,
#         "lon": -51.19
#     },
#     "dt": 1601423270,
#     "id": 3420768,
#     "main": {
#         "feels_like": 19.27,
#         "humidity": 63,
#         "pressure": 1015,
#         "temp": 28.4,
#         "temp_max": 28.4,
#         "temp_min": 28.4
#     },
#     "name": "Qasigiannguit",
#     "sys": {
#         "country": "GL",
#         "id": 165,
#         "sunrise": 1601371978,
#         "sunset": 1601413005,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 6.93
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=qasigiannguit
# {
#     "base": "stations",
#     "clouds": {
#         "all": 78
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.22,
#         "lon": 75.98
#     },
#     "dt": 1601423270,
#     "id": 1490003,
#     "main": {
#         "feels_like": 29.12,
#         "grnd_level": 1022,
#         "humidity": 85,
#         "pressure": 1036,
#         "sea_level": 1036,
#         "temp": 35.26,
#         "temp_max": 35.26,
#         "temp_min": 35.26
#     },
#     "name": "Tatarsk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601427408,
#         "sunset": 1601469306
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 259,
#         "speed": 4.34
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=tatarsk
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.55,
#         "lon": 16.43
#     },
#     "dt": 1601423271,
#     "id": 3354071,
#     "main": {
#         "feels_like": 44.37,
#         "grnd_level": 1014,
#         "humidity": 74,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 55.72,
#         "temp_max": 55.72,
#         "temp_min": 55.72
#     },
#     "name": "Oranjemund",
#     "sys": {
#         "country": "NA",
#         "sunrise": 1601440432,
#         "sunset": 1601484860
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 19.19
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=oranjemund
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -45.58,
#         "lon": -72.07
#     },
#     "dt": 1601423265,
#     "id": 3894426,
#     "main": {
#         "feels_like": 33.64,
#         "humidity": 60,
#         "pressure": 1006,
#         "temp": 39.2,
#         "temp_max": 39.2,
#         "temp_min": 39.2
#     },
#     "name": "Coyhaique",
#     "sys": {
#         "country": "CL",
#         "id": 8491,
#         "sunrise": 1601374963,
#         "sunset": 1601420040,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 2.24
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=coihaique
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.74,
#         "lon": -97.86
#     },
#     "dt": 1601423271,
#     "id": 6165406,
#     "main": {
#         "feels_like": 43.38,
#         "humidity": 62,
#         "pressure": 1001,
#         "temp": 55.4,
#         "temp_max": 55.4,
#         "temp_min": 55.4
#     },
#     "name": "Thompson",
#     "sys": {
#         "country": "CA",
#         "id": 935,
#         "sunrise": 1601382685,
#         "sunset": 1601424694,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09d",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "gust": 26.4,
#         "speed": 18.34
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=thompson
# {
#     "base": "stations",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -24.79,
#         "lon": -50.01
#     },
#     "dt": 1601423189,
#     "id": 3466704,
#     "main": {
#         "feels_like": 67.55,
#         "grnd_level": 906,
#         "humidity": 93,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 65.19,
#         "temp_max": 65.19,
#         "temp_min": 65.19
#     },
#     "name": "Castro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1601370096,
#         "sunset": 1601414321
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 84,
#         "speed": 3.8
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=castro
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.88,
#         "lon": 147.33
#     },
#     "dt": 1601423272,
#     "id": 2163355,
#     "main": {
#         "feels_like": 48.67,
#         "humidity": 76,
#         "pressure": 1010,
#         "temp": 54.5,
#         "temp_max": 55.99,
#         "temp_min": 53.6
#     },
#     "name": "Hobart",
#     "rain": {
#         "1h": 1.38
#     },
#     "sys": {
#         "country": "AU",
#         "id": 9545,
#         "sunrise": 1601408736,
#         "sunset": 1601453738,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 9.17
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=hobart
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1601423272,
#     "id": 4032243,
#     "main": {
#         "feels_like": 81.93,
#         "humidity": 88,
#         "pressure": 1012,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1601486518,
#         "sunset": 1601530735,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "gust": 24.16,
#         "speed": 12.75
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=vaini
# {
#     "base": "stations",
#     "clouds": {
#         "all": 36
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.05,
#         "lon": 179.32
#     },
#     "dt": 1601423273,
#     "id": 2126710,
#     "main": {
#         "feels_like": 39.69,
#         "grnd_level": 1013,
#         "humidity": 65,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 44.13,
#         "temp_max": 44.13,
#         "temp_min": 44.13
#     },
#     "name": "Beringovskiy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601402836,
#         "sunset": 1601444287
#     },
#     "timezone": 43200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 113,
#         "speed": 1.83
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=beringovskiy
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 16.89,
#         "lon": -24.98
#     },
#     "dt": 1601423273,
#     "id": 3374462,
#     "main": {
#         "feels_like": 73.92,
#         "humidity": 61,
#         "pressure": 1015,
#         "temp": 80.6,
#         "temp_max": 80.6,
#         "temp_min": 80.6
#     },
#     "name": "Mindelo",
#     "sys": {
#         "country": "CV",
#         "id": 2467,
#         "sunrise": 1601364585,
#         "sunset": 1601407820,
#         "type": 1
#     },
#     "timezone": -3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 21.92
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=mindelo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.14,
#         "lon": -5.02
#     },
#     "dt": 1601423273,
#     "id": 2288105,
#     "main": {
#         "feels_like": 80.69,
#         "grnd_level": 1013,
#         "humidity": 93,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 75.92,
#         "temp_max": 75.92,
#         "temp_min": 75.92
#     },
#     "name": "Grand-Lahou",
#     "rain": {
#         "1h": 0.55
#     },
#     "sys": {
#         "country": "CI",
#         "sunrise": 1601359669,
#         "sunset": 1601403157
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 201,
#         "speed": 8.63
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=grand-lahou
# {
#     "base": "stations",
#     "clouds": {
#         "all": 15
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.9,
#         "lon": -24.5
#     },
#     "dt": 1601423274,
#     "id": 3374210,
#     "main": {
#         "feels_like": 81.66,
#         "grnd_level": 1009,
#         "humidity": 75,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 79.57,
#         "temp_max": 79.57,
#         "temp_min": 79.57
#     },
#     "name": "S\u00e3o Filipe",
#     "sys": {
#         "country": "CV",
#         "sunrise": 1601364448,
#         "sunset": 1601407727
#     },
#     "timezone": -3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 52,
#         "speed": 10.69
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=sao filipe
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.42,
#         "lon": 30.78
#     },
#     "dt": 1601422989,
#     "id": 352628,
#     "main": {
#         "feels_like": 74.61,
#         "grnd_level": 1006,
#         "humidity": 56,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 78.82,
#         "temp_max": 78.82,
#         "temp_min": 78.82
#     },
#     "name": "Ma\u0163\u0101y",
#     "sys": {
#         "country": "EG",
#         "sunrise": 1601437758,
#         "sunset": 1601480647
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 8,
#         "speed": 14.5
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=matay
# {
#     "base": "stations",
#     "clouds": {
#         "all": 67
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.06,
#         "lon": 9.24
#     },
#     "dt": 1601423274,
#     "id": 2467368,
#     "main": {
#         "feels_like": 62.71,
#         "humidity": 77,
#         "pressure": 1016,
#         "temp": 64.4,
#         "temp_max": 64.4,
#         "temp_min": 64.4
#     },
#     "name": "Sajanan",
#     "sys": {
#         "country": "TN",
#         "id": 1195,
#         "sunrise": 1601443059,
#         "sunset": 1601485683,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 6.93
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=sajanan
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.18,
#         "lon": -51.72
#     },
#     "dt": 1601423166,
#     "id": 3421319,
#     "main": {
#         "feels_like": 21.11,
#         "humidity": 68,
#         "pressure": 1015,
#         "temp": 31.1,
#         "temp_max": 32,
#         "temp_min": 30.2
#     },
#     "name": "Nuuk",
#     "sys": {
#         "country": "GL",
#         "id": 86,
#         "sunrise": 1601371873,
#         "sunset": 1601413365,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 9.17
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=nuuk
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=taolanaro
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.52,
#         "lon": -28.7
#     },
#     "dt": 1601423231,
#     "id": 3372707,
#     "main": {
#         "feels_like": 62.24,
#         "grnd_level": 1026,
#         "humidity": 69,
#         "pressure": 1029,
#         "sea_level": 1029,
#         "temp": 66.74,
#         "temp_max": 66.74,
#         "temp_min": 66.74
#     },
#     "name": "Ribeira Grande",
#     "sys": {
#         "country": "PT",
#         "sunrise": 1601365740,
#         "sunset": 1601408450
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 19,
#         "speed": 11.45
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ribeira grande
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.22,
#         "lon": 155.63
#     },
#     "dt": 1601423234,
#     "id": 2094027,
#     "main": {
#         "feels_like": 91.53,
#         "grnd_level": 1006,
#         "humidity": 63,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 85.75,
#         "temp_max": 85.75,
#         "temp_min": 85.75
#     },
#     "name": "Kieta",
#     "sys": {
#         "country": "PG",
#         "sunrise": 1601407372,
#         "sunset": 1601451120
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 101,
#         "speed": 4.83
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kieta
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.89,
#         "lon": -60.57
#     },
#     "dt": 1601423276,
#     "id": 3841490,
#     "main": {
#         "feels_like": 58.96,
#         "humidity": 67,
#         "pressure": 1005,
#         "temp": 62.01,
#         "temp_max": 62.01,
#         "temp_min": 62.01
#     },
#     "name": "Pergamino",
#     "sys": {
#         "country": "AR",
#         "id": 2029960,
#         "sunrise": 1601372474,
#         "sunset": 1601417010,
#         "type": 3
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 68,
#         "gust": 8.01,
#         "speed": 5.99
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=pergamino
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.06,
#         "lon": -103.15
#     },
#     "dt": 1601423277,
#     "id": 5768244,
#     "main": {
#         "feels_like": 62.35,
#         "humidity": 19,
#         "pressure": 1014,
#         "temp": 76.39,
#         "temp_max": 78.8,
#         "temp_min": 75
#     },
#     "name": "Rapid Valley",
#     "sys": {
#         "country": "US",
#         "id": 5623,
#         "sunrise": 1601383708,
#         "sunset": 1601426209,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "gust": 27.51,
#         "speed": 18.34
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=rapid valley
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=umm jarr
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 69
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.63,
#         "lon": 147.92
#     },
#     "dt": 1601423256,
#     "id": 2126123,
#     "main": {
#         "feels_like": 34.29,
#         "grnd_level": 996,
#         "humidity": 81,
#         "pressure": 1001,
#         "sea_level": 1001,
#         "temp": 41.32,
#         "temp_max": 41.32,
#         "temp_min": 41.32
#     },
#     "name": "Chokurdakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601410820,
#         "sunset": 1601451372
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 151,
#         "speed": 7.25
#     }
# }
# ...
#         "sunrise": 1601387535,
#         "sunset": 1601430325,
#         "type": 3
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 328,
#         "gust": 4,
#         "speed": 1.01
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=santa barbara
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 26.96,
#         "lon": 56.27
#     },
#     "dt": 1601423453,
#     "id": 119374,
#     "main": {
#         "feels_like": 89.33,
#         "humidity": 88,
#         "pressure": 1005,
#         "temp": 80.6,
#         "temp_max": 80.6,
#         "temp_min": 80.6
#     },
#     "name": "Qeshm",
#     "sys": {
#         "country": "IR",
#         "id": 7480,
#         "sunrise": 1601431619,
#         "sunset": 1601474554,
#         "type": 1
#     },
#     "timezone": 12600,
#     "visibility": 3000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 4.7
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=qeshm
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=wulanhaote
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.43,
#         "lon": 26.4
#     },
#     "dt": 1601423453,
#     "id": 686090,
#     "main": {
#         "feels_like": 47.75,
#         "humidity": 81,
#         "pressure": 1004,
#         "temp": 54,
#         "temp_max": 54,
#         "temp_min": 54
#     },
#     "name": "As\u0103u",
#     "sys": {
#         "country": "RO",
#         "id": 2033571,
#         "sunrise": 1601439108,
#         "sunset": 1601481399,
#         "type": 3
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 258,
#         "speed": 10.45
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=asau
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=yialos
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.34,
#         "lon": 106.1
#     },
#     "dt": 1601423453,
#     "id": 1630058,
#     "main": {
#         "feels_like": 83.41,
#         "humidity": 78,
#         "pressure": 1009,
#         "temp": 78.93,
#         "temp_max": 82,
#         "temp_min": 77
#     },
#     "name": "Karaton",
#     "sys": {
#         "country": "ID",
#         "id": 9384,
#         "sunrise": 1601419253,
#         "sunset": 1601463007,
#         "type": 1
#     },
#     "timezone": 25200,
#     "visibility": 5000,
#     "weather": [
#         {
#             "description": "haze",
#             "icon": "50d",
#             "id": 721,
#             "main": "Haze"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 6.93
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=karaton
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 2.67,
#         "lon": 72.89
#     },
#     "dt": 1601423454,
#     "id": 1337607,
#     "main": {
#         "feels_like": 86.99,
#         "grnd_level": 1008,
#         "humidity": 75,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 82.49,
#         "temp_max": 82.49,
#         "temp_min": 82.49
#     },
#     "name": "Kudahuvadhoo",
#     "sys": {
#         "country": "MV",
#         "sunrise": 1601427331,
#         "sunset": 1601470866
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 237,
#         "speed": 9.13
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=kudahuvadhoo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 58.61,
#         "lon": 5.65
#     },
#     "dt": 1601423454,
#     "id": 3132644,
#     "main": {
#         "feels_like": 40.93,
#         "humidity": 99,
#         "pressure": 1002,
#         "temp": 52.66,
#         "temp_max": 53.01,
#         "temp_min": 52
#     },
#     "name": "Varhaug",
#     "rain": {
#         "1h": 0.13
#     },
#     "sys": {
#         "country": "NO",
#         "id": 2034752,
#         "sunrise": 1601444419,
#         "sunset": 1601486047,
#         "type": 3
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 128,
#         "speed": 22.19
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=varhaug
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.79,
#         "lon": 74.52
#     },
#     "dt": 1601423455,
#     "id": 1540711,
#     "main": {
#         "feels_like": 31.33,
#         "grnd_level": 1008,
#         "humidity": 94,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": 40.64,
#         "temp_max": 40.64,
#         "temp_min": 40.64
#     },
#     "name": "Muravlenko",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601428069,
#         "sunset": 1601469346
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 323,
#         "speed": 12.26
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=muravlenko
# {
#     "base": "stations",
#     "clouds": {
#         "all": 27
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.9,
#         "lon": 34.58
#     },
#     "dt": 1601423455,
#     "id": 159218,
#     "main": {
#         "feels_like": 58.3,
#         "grnd_level": 860,
#         "humidity": 75,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 61.66,
#         "temp_max": 61.66,
#         "temp_min": 61.66
#     },
#     "name": "Ilembula",
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1601436379,
#         "sunset": 1601480203
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 148,
#         "speed": 7.99
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ilembula
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.21,
#         "lon": 57.76
#     },
#     "dt": 1601423455,
#     "id": 1106643,
#     "main": {
#         "feels_like": 73.2,
#         "humidity": 88,
#         "pressure": 1018,
#         "temp": 71.29,
#         "temp_max": 71.6,
#         "temp_min": 71.01
#     },
#     "name": "Quatre Cocos",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1601430659,
#         "sunset": 1601474799,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 8.05
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=quatre cocos
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 49.87,
#         "lon": -111.37
#     },
#     "dt": 1601423456,
#     "id": 5906757,
#     "main": {
#         "feels_like": 51.89,
#         "humidity": 42,
#         "pressure": 1019,
#         "temp": 63.77,
#         "temp_max": 64.4,
#         "temp_min": 63
#     },
#     "name": "Bow Island",
#     "sys": {
#         "country": "CA",
#         "id": 978,
#         "sunrise": 1601385793,
#         "sunset": 1601428069,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "gust": 24.16,
#         "speed": 17.22
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=bow island
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -41.87,
#         "lon": -73.82
#     },
#     "dt": 1601423456,
#     "id": 3899695,
#     "main": {
#         "feels_like": 27.55,
#         "humidity": 100,
#         "pressure": 1009,
#         "temp": 35.71,
#         "temp_max": 37.99,
#         "temp_min": 33.8
#     },
#     "name": "Ancud",
#     "sys": {
#         "country": "CL",
#         "id": 8512,
#         "sunrise": 1601375479,
#         "sunset": 1601420364,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 1700,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 9.17
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=ancud
# {
#     "base": "stations",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 58.54,
#         "lon": 15.04
#     },
#     "dt": 1601423456,
#     "id": 2690960,
#     "main": {
#         "feels_like": 39.61,
#         "humidity": 93,
#         "pressure": 1018,
#         "temp": 43.39,
#         "temp_max": 44.6,
#         "temp_min": 42.8
#     },
#     "name": "Motala",
#     "sys": {
#         "country": "SE",
#         "id": 1753,
#         "sunrise": 1601442159,
#         "sunset": 1601483800,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 100,
#     "weather": [
#         {
#             "description": "fog",
#             "icon": "50n",
#             "id": 741,
#             "main": "Fog"
#         }
#     ],
#     "wind": {
#         "deg": 134,
#         "speed": 3.31
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=motala
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.99,
#         "lon": -74.95
#     },
#     "dt": 1601423348,
#     "id": 3671497,
#     "main": {
#         "feels_like": 94.48,
#         "humidity": 79,
#         "pressure": 1006,
#         "temp": 84.2,
#         "temp_max": 84.2,
#         "temp_min": 84.2
#     },
#     "name": "Puerto Colombia",
#     "sys": {
#         "country": "CO",
#         "id": 8584,
#         "sunrise": 1601376514,
#         "sunset": 1601419871,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 2.24
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=puerto colombia
# {
#     "cod": "404",
#     "message": "city not found"
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=temaraia
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 14
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.74,
#         "lon": -87.67
#     },
#     "dt": 1601423457,
#     "id": 4078964,
#     "main": {
#         "feels_like": 57.79,
#         "humidity": 69,
#         "pressure": 1014,
#         "temp": 61.36,
#         "temp_max": 62.01,
#         "temp_min": 60.01
#     },
#     "name": "Muscle Shoals",
#     "sys": {
#         "country": "US",
#         "id": 2011186,
#         "sunrise": 1601379848,
#         "sunset": 1601422641,
#         "type": 3
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 304,
#         "speed": 7.02
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=muscle shoals
# {
#     "base": "stations",
#     "clouds": {
#         "all": 82
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.6,
#         "lon": 26.69
#     },
#     "dt": 1601423457,
#     "id": 364933,
#     "main": {
#         "feels_like": 83.17,
#         "grnd_level": 942,
#         "humidity": 50,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 86.86,
#         "temp_max": 86.86,
#         "temp_min": 86.86
#     },
#     "name": "Umm Kaddadah",
#     "sys": {
#         "country": "SD",
#         "sunrise": 1601438550,
#         "sunset": 1601481818
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 212,
#         "speed": 16.69
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=umm kaddadah
# {
#     "base": "stations",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 54.43,
#         "lon": 31.9
#     },
#     "dt": 1601423457,
#     "id": 525426,
#     "main": {
#         "feels_like": 41.23,
#         "grnd_level": 994,
#         "humidity": 72,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 48.74,
#         "temp_max": 48.74,
#         "temp_min": 48.74
#     },
#     "name": "Sobolevo",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1601437979,
#         "sunset": 1601479889
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 97,
#         "speed": 9.44
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=sobolevo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 72
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.86,
#         "lon": 35.38
#     },
#     "dt": 1601423353,
#     "id": 1045114,
#     "main": {
#         "feels_like": 77.5,
#         "grnd_level": 1017,
#         "humidity": 84,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 73.24,
#         "temp_max": 73.24,
#         "temp_min": 73.24
#     },
#     "name": "Inhambane",
#     "rain": {
#         "1h": 0.5
#     },
#     "sys": {
#         "country": "MZ",
#         "sunrise": 1601435969,
#         "sunset": 1601480229
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 151,
#         "speed": 4.34
#     }
# }
# http://api.openweathermap.org/data/2.5/weather?appid=a49a129424c060972dd3e8502d0d8dd1&units=Imperial&q=inhambane

# %%
city_data_df = pd.DataFrame(all_city_data)
city_data_df.head()
# Out:
#         City  Latitude  Longitude  Temperature  Humidity  Clouds   Wind  \
# 0    kampene     -3.60      26.67        66.45        97      96   1.86
# 1    ushuaia    -54.80     -68.30        33.80        86      75  20.80
# 2     albany     42.60     -73.97        62.01        77      79   5.41
# 3  mount isa    -20.73     139.50        84.20        32      10   2.24
# 4     lumeje    -11.55      20.78        69.31        80      96   7.81
#
#   Country        Date
# 0      CD  1601423260
# 1      AR  1601423196
# 2      US  1601423222
# 3      AU  1601423261
# 4      AO  1601423261

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
